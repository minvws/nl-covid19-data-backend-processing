-- %% [markdown]
-- # **INTRODUCTIONS**
--
-- ---
--
-- The code is separated into multiple sections:
--
-- 1. **[Tables](#tables)**
-- 2. **[Stored Procedures](#stored-procedures)**
-- 3. **[Datatino Configurations](#datatino-configurations)**

-- %% [markdown]
-- # **DEPENDENCIES**
--
-- ---
--
-- ```json
-- {
--     "depends-on": [
--         "src/common/schemas.ipynb"
--     ]
-- }
-- ```

-- %% [markdown]
-- # **TABLES**
--
-- ---

-- %% [markdown]
-- ### STATICS

-- %%
-- COPYRIGHT (C) 2020 DE STAAT DER NEDERLANDEN, MINISTERIE VAN VOLKSGEZONDHEID, WELZIJN EN SPORT.
-- LICENSED UNDER THE EUROPEAN UNION PUBLIC LICENCE V. 1.2 - SEE HTTPS://GITHUB.COM/MINVWS/NL-CONTACT-TRACING-APP-COORDINATION FOR MORE INFORMATION.

SET ANSI_NULLS ON
GO

SET QUOTED_IDENTIFIER ON
GO

-- 1) CREATE STATIC TABLE(S).....
DROP TABLE IF EXISTS [VWSSTATIC].[CBS_POPULATION]

CREATE TABLE [VWSSTATIC].[CBS_POPULATION] (
    [ID] [INT] PRIMARY KEY IDENTITY(1,1),
	[DATE_LAST_INSERTED] DATETIME DEFAULT GETDATE(),
    [GM_CODE]  [VARCHAR](100) NULL,
    [GM_NAME] [VARCHAR](100) NULL,
    [AGE] [INT] NULL,
    [GENDEER] [VARCHAR](100) NULL,
    [DATE_OF_POLL] [DATE] NULL,
    [POPULATION] [INT] NULL,
    [VR_CODE] [VARCHAR](100) NULL,
    [VR_NAME] [VARCHAR](100) NULL,
    [PROVINCE_CODE] [VARCHAR](100) NULL,
    [PROVINCE_NAME] [VARCHAR](100) NULL,
    [GGD_CODE] [VARCHAR](100) NULL,
    [GGD_NAME] [VARCHAR](100) NULL,
    [AGE_GROUP] [VARCHAR](100) NULL
);
GO

-- 2) CREATE STATIC INDEX(ES).....
CREATE NONCLUSTERED INDEX [NCIX_DLI_CBS_POPULATION] ON [VWSSTATIC].[CBS_POPULATION] (
    [DATE_LAST_INSERTED]
) WITH (STATISTICS_NORECOMPUTE = OFF, DROP_EXISTING = OFF, ONLINE = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY];
GO

-- %% [markdown]
-- #### SAFETY REGIONS

-- %%
-- COPYRIGHT (C) 2020 DE STAAT DER NEDERLANDEN, MINISTERIE VAN VOLKSGEZONDHEID, WELZIJN EN SPORT.
-- LICENSED UNDER THE EUROPEAN UNION PUBLIC LICENCE V. 1.2 - SEE HTTPS://GITHUB.COM/MINVWS/NL-CONTACT-TRACING-APP-COORDINATION FOR MORE INFORMATION.

SET ANSI_NULLS ON
GO

SET QUOTED_IDENTIFIER ON
GO

-- 1) CREATE STATIC TABLE(S).....
IF NOT EXISTS(SELECT * FROM SYS.TABLES WHERE [OBJECT_ID] = OBJECT_ID(N'[VWSSTATIC].[CBS_POPULATION_VR]'))
CREATE TABLE [VWSSTATIC].[CBS_POPULATION_VR](
  [ID] [INT] PRIMARY KEY IDENTITY(1,1),
	[DATE_LAST_INSERTED] [DATETIME] DEFAULT GETDATE(),
  [VR_CODE]  [VARCHAR](10) NULL,
  [DATE_OF_POLL] [DATE] NULL,
  [POPULATION] [INT] NULL
);
GO

-- 2) CREATE STATIC INDEX(ES).....
IF NOT EXISTS(SELECT * FROM SYS.INDEXES WHERE [NAME] = 'NCIX_DLI_CBS_POPULATION_VR')
CREATE NONCLUSTERED INDEX [NCIX_DLI_CBS_POPULATION_VR] ON [VWSSTATIC].[CBS_POPULATION_VR] (
  [DATE_LAST_INSERTED]
) WITH (STATISTICS_NORECOMPUTE = OFF, DROP_EXISTING = OFF, ONLINE = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY];
GO

-- %% [markdown]
-- #### NATIONAL NL

-- %%
-- COPYRIGHT (C) 2020 DE STAAT DER NEDERLANDEN, MINISTERIE VAN VOLKSGEZONDHEID, WELZIJN EN SPORT.
-- LICENSED UNDER THE EUROPEAN UNION PUBLIC LICENCE V. 1.2 - SEE HTTPS://GITHUB.COM/MINVWS/NL-CONTACT-TRACING-APP-COORDINATION FOR MORE INFORMATION.

SET ANSI_NULLS ON
GO

SET QUOTED_IDENTIFIER ON
GO

-- 1) CREATE STATIC TABLE(S).....
IF NOT EXISTS(SELECT * FROM SYS.TABLES WHERE [OBJECT_ID] = OBJECT_ID(N'[VWSSTATIC].[CBS_POPULATION_NL]'))
CREATE TABLE [VWSSTATIC].[CBS_POPULATION_NL](
    [ID] [INT] PRIMARY KEY IDENTITY(1,1),
	[DATE_LAST_INSERTED] [DATETIME] DEFAULT GETDATE(),
    [DATE_OF_POLL] [DATE] NULL,
    [POPULATION] [INT] NULL
);
GO

-- 2) CREATE STATIC INDEX(ES).....
IF NOT EXISTS(SELECT * FROM SYS.INDEXES WHERE [NAME] = 'NCIX_DLI_CBS_POPULATION_NL')
CREATE NONCLUSTERED INDEX [NCIX_DLI_CBS_POPULATION_NL] ON [VWSSTATIC].[CBS_POPULATION_NL] (
    [DATE_LAST_INSERTED]
) WITH (STATISTICS_NORECOMPUTE = OFF, DROP_EXISTING = OFF, ONLINE = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY];
GO

-- %% [markdown]
-- #### MUNICIPALITIES

-- %%
-- COPYRIGHT (C) 2020 DE STAAT DER NEDERLANDEN, MINISTERIE VAN VOLKSGEZONDHEID, WELZIJN EN SPORT.
-- LICENSED UNDER THE EUROPEAN UNION PUBLIC LICENCE V. 1.2 - SEE HTTPS://GITHUB.COM/MINVWS/NL-CONTACT-TRACING-APP-COORDINATION FOR MORE INFORMATION.

SET ANSI_NULLS ON
GO

SET QUOTED_IDENTIFIER ON
GO

-- 1) CREATE STATIC TABLE(S).....
IF NOT EXISTS(SELECT * FROM SYS.TABLES WHERE [OBJECT_ID] = OBJECT_ID(N'[VWSSTATIC].[CBS_POPULATION_GM]'))
CREATE TABLE [VWSSTATIC].[CBS_POPULATION_GM] (
    [ID] [INT] PRIMARY KEY IDENTITY(1,1),
	[DATE_LAST_INSERTED] [DATETIME] DEFAULT GETDATE(),
    [GM_CODE]  [VARCHAR](10) NULL,
    [DATE_OF_POLL] [DATE] NULL,
    [POPULATION] [INT] NULL
);
GO

-- 3) CREATE STATIC INDEX(ES).....
IF NOT EXISTS(SELECT * FROM SYS.INDEXES WHERE [NAME] = 'NCIX_DLI_CBS_POPULATION_GM')
CREATE NONCLUSTERED INDEX [NCIX_DLI_CBS_POPULATION_GM] ON [VWSSTATIC].[CBS_POPULATION_GM] (
    [DATE_LAST_INSERTED]
) WITH (STATISTICS_NORECOMPUTE = OFF, DROP_EXISTING = OFF, ONLINE = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY];
GO

-- %% [markdown]
-- #### AGE GROUPS

-- %%
-- COPYRIGHT (C) 2020 DE STAAT DER NEDERLANDEN, MINISTERIE VAN VOLKSGEZONDHEID, WELZIJN EN SPORT.
-- LICENSED UNDER THE EUROPEAN UNION PUBLIC LICENCE V. 1.2 - SEE HTTPS://GITHUB.COM/MINVWS/AGEGROUP_10-CONTACT-TRACING-APP-COORDINATION FOR MORE INFORMATION.

SET ANSI_NULLS ON
GO

SET QUOTED_IDENTIFIER ON
GO

-- 1) CREATE STATIC TABLE(S).....
IF NOT EXISTS(SELECT * FROM SYS.TABLES WHERE [OBJECT_ID] = OBJECT_ID(N'[VWSSTATIC].[CBS_POPULATION_PER_AGE_GROUP]'))
CREATE TABLE [VWSSTATIC].[CBS_POPULATION_PER_AGE_GROUP](
  [ID] [INT] PRIMARY KEY IDENTITY(1,1),
	[DATE_LAST_INSERTED] DATETIME DEFAULT GETDATE(),
  [AGE_GROUP] [VARCHAR](10) NULL,
  [DATE_OF_POLL] [DATE] NULL,
  [POPULATION] [INT] NULL
);
GO

-- 3) CREATE STATIC INDEX(ES).....
IF NOT EXISTS(SELECT * FROM SYS.INDEXES WHERE [NAME] = 'NCIX_DLI_CBS_POPULATION_PER_AGE_GROUP')
CREATE NONCLUSTERED INDEX [NCIX_DLI_CBS_POPULATION_PER_AGE_GROUP] ON [VWSSTATIC].[CBS_POPULATION_PER_AGE_GROUP] (
  [DATE_LAST_INSERTED]
) WITH (STATISTICS_NORECOMPUTE = OFF, DROP_EXISTING = OFF, ONLINE = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY];
GO

-- %% [markdown]
-- #### AGE GROUP DECEASED

-- %%
-- COPYRIGHT (C) 2020 DE STAAT DER NEDERLANDEN, MINISTERIE VAN VOLKSGEZONDHEID, WELZIJN EN SPORT.
-- LICENSED UNDER THE EUROPEAN UNION PUBLIC LICENCE V. 1.2 - SEE HTTPS://GITHUB.COM/MINVWS/AGEGROUP_DECEASED-CONTACT-TRACING-APP-COORDINATION FOR MORE INFORMATION.

SET ANSI_NULLS ON
GO

SET QUOTED_IDENTIFIER ON
GO

-- 1) CREATE STATIC TABLE(S).....
IF NOT EXISTS(SELECT * FROM SYS.TABLES WHERE [OBJECT_ID] = OBJECT_ID(N'[VWSSTATIC].[CBS_POPULATION_AGE_GROUP_DECEASED]'))
CREATE TABLE [VWSSTATIC].[CBS_POPULATION_AGE_GROUP_DECEASED](
	[ID] [INT] PRIMARY KEY IDENTITY(1,1),
	[DATE_LAST_INSERTED] [DATETIME] DEFAULT GETDATE(),
	[AGE_GROUP] [VARCHAR](10) NULL,
	[DATE_OF_POLL] [DATE] NULL,
	[POPULATION] [INT] NULL,
	[POPULATION_TOTAL] [INT] NULL,
	[INHABITANTS_PERCENTAGE] [DECIMAL](19,3) NULL
);
GO

-- 2) CREATE STATIC INDEX(ES).....
IF NOT EXISTS(SELECT * FROM SYS.INDEXES WHERE [NAME] = 'NCIX_DLI_DOF_AG_POP_CBS_POPULATION_AGE_GROUP_DECEASED')
CREATE NONCLUSTERED INDEX [NCIX_DLI_DOF_AG_POP_CBS_POPULATION_AGE_GROUP_DECEASED] ON [VWSSTATIC].[CBS_POPULATION_AGE_GROUP_DECEASED] (
	[DATE_LAST_INSERTED],
	[DATE_OF_POLL], 
	[AGE_GROUP], 
	[POPULATION]
) WITH (STATISTICS_NORECOMPUTE = OFF, DROP_EXISTING = OFF, ONLINE = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY];
GO

-- %% [markdown]
-- #### AGE GROUP HOSPITAL IC

-- %%
-- COPYRIGHT (C) 2020 DE STAAT DER NEDERLANDEN, MINISTERIE VAN VOLKSGEZONDHEID, WELZIJN EN SPORT.
-- LICENSED UNDER THE EUROPEAN UNION PUBLIC LICENCE V. 1.2 - SEE HTTPS://GITHUB.COM/MINVWS/AGEGROUP_HOSPITAL_IC-CONTACT-TRACING-APP-COORDINATION FOR MORE INFORMATION.

SET ANSI_NULLS ON
GO

SET QUOTED_IDENTIFIER ON
GO

-- 1) CREATE STATIC TABLE(S).....
IF NOT EXISTS(SELECT * FROM SYS.TABLES WHERE [OBJECT_ID] = OBJECT_ID(N'[VWSSTATIC].[CBS_POPULATION_AGE_GROUP_HOSPITAL_IC]'))
CREATE TABLE [VWSSTATIC].[CBS_POPULATION_AGE_GROUP_HOSPITAL_IC] (
	[ID] [INT] PRIMARY KEY IDENTITY(1,1),
	[DATE_LAST_INSERTED] DATETIME DEFAULT GETDATE(),
	[AGE_GROUP] [VARCHAR](10) NULL,
	[DATE_OF_POLL] [DATE] NULL,
	[POPULATION] [INT] NULL,
	[POPULATION_TOTAL] [INT] NULL,
	[INHABITANTS_PERCENTAGE] [DECIMAL](19,3) NULL
);
GO

-- 2) CREATE STATIC INDEX(ES).....
IF NOT EXISTS(SELECT * FROM SYS.INDEXES WHERE [NAME] = 'NCIX_DLI_DOF_AG_POP_CBS_POPULATION_AGE_GROUP_HOSPITAL_IC')
CREATE NONCLUSTERED INDEX [NCIX_DLI_DOF_AG_POP_CBS_POPULATION_AGE_GROUP_HOSPITAL_IC] ON [VWSSTATIC].[CBS_POPULATION_AGE_GROUP_HOSPITAL_IC] (
	[DATE_LAST_INSERTED],
	[DATE_OF_POLL], 
	[AGE_GROUP], 
	[POPULATION]
) WITH (STATISTICS_NORECOMPUTE = OFF, DROP_EXISTING = OFF, ONLINE = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY];
GO

-- %% [markdown]
-- # **STORED PROCEDURES**
--
-- ---

-- %% [markdown]
-- ### STATIC &rarr; STATIC MAPPING

-- %%
-- COPYRIGHT (C) 2020 DE STAAT DER NEDERLANDEN, MINISTERIE VAN   VOLKSGEZONDHEID, WELZIJN EN SPORT.
-- LICENSED UNDER THE EUROPEAN UNION PUBLIC LICENCE V. 1.2 - SEE HTTPS://GITHUB.COM/MINVWS/NL-CONTACT-TRACING-APP-COORDINATIONFOR MORE INFORMATION.

CREATE OR ALTER PROCEDURE [DBO].[SP_CBS_POPULATION_STATIC_TO_STATIC]
AS
BEGIN

    BEGIN TRANSACTION;

    UPDATE [VWSSTATIC].[CBS_POPULATION]
    SET [AGE_GROUP] = CASE 
            WHEN CAST([AGE] AS INT) >= 0  AND CAST([AGE] AS INT) <= 9  THEN '0-19'
            WHEN CAST([AGE] AS INT) >= 10 AND CAST([AGE] AS INT) <= 19 THEN '0-19'
            WHEN CAST([AGE] AS INT) >= 20 AND CAST([AGE] AS INT) <= 29 THEN '20-29'
            WHEN CAST([AGE] AS INT) >= 30 AND CAST([AGE] AS INT) <= 39 THEN '30-39'
            WHEN CAST([AGE] AS INT) >= 40 AND CAST([AGE] AS INT) <= 49 THEN '40-49'
            WHEN CAST([AGE] AS INT) >= 50 AND CAST([AGE] AS INT) <= 59 THEN '50-59'
            WHEN CAST([AGE] AS INT) >= 60 AND CAST([AGE] AS INT) <= 69 THEN '60-69'
            WHEN CAST([AGE] AS INT) >= 70 AND CAST([AGE] AS INT) <= 79 THEN '70-79'
            WHEN CAST([AGE] AS INT) >= 80 AND CAST([AGE] AS INT) <= 89 THEN '80-89'
            WHEN CAST([AGE] AS INT) >= 90 THEN '90+'
            ELSE NULL
        END
    WHERE [DATE_LAST_INSERTED] = (SELECT MAX([DATE_LAST_INSERTED]) FROM [VWSSTATIC].[CBS_POPULATION])
        AND [AGE_GROUP] IS NULL 
        AND [ID] = [ID]

    -- 1) NATIONAL NL
    EXEC [DBO].[SP_CBS_POPULATION_NL_STATIC_TO_STATIC]

    -- 2) SAFETY REGIONS
    EXEC [DBO].[SP_CBS_POPULATION_VR_STATIC_TO_STATIC]
    
    -- 3) MUNICIPALITIES
    EXEC [DBO].[SP_CBS_POPULATION_GM_STATIC_TO_STATIC]

    -- 4) AGE GROUP HOSPITAL IC
    EXEC [DBO].[SP_CBS_POPULATION_PER_AGE_GROUP_HOSPITAL_IC_STATIC_TO_STATIC]

    -- 5) AGE GROUP DECEASED
    EXEC [DBO].[SP_CBS_POPULATION_PER_AGE_GROUP_DECEASED_STATIC_TO_STATIC]
    
    -- 6) AGE GROUPS
    EXEC [DBO].[SP_CBS_POPULATION_PER_AGE_GROUP_STATIC_TO_STATIC]
    
    -- 7) DROP TABLES OR RECORDS
    TRUNCATE TABLE [VWSSTATIC].[CBS_POPULATION];

    COMMIT;
END
GO

-- %% [markdown]
-- #### NATIONAL NL

-- %%
-- COPYRIGHT (C) 2020 DE STAAT DER NEDERLANDEN, MINISTERIE VAN   VOLKSGEZONDHEID, WELZIJN EN SPORT.
-- LICENSED UNDER THE EUROPEAN UNION PUBLIC LICENCE V. 1.2 - SEE HTTPS://GITHUB.COM/MINVWS/NL-CONTACT-TRACING-APP-COORDINATIONFOR MORE INFORMATION.

CREATE OR ALTER PROCEDURE [DBO].[SP_CBS_POPULATION_NL_STATIC_TO_STATIC]
AS
BEGIN

    BEGIN TRANSACTION;

    INSERT INTO [VWSSTATIC].[CBS_POPULATION_NL] ( 
        [DATE_OF_POLL], 
        [POPULATION] 
    )
    SELECT
        [DATE_OF_POLL],
        SUM([POPULATION])
    FROM [VWSSTATIC].[CBS_POPULATION]
    WHERE [DATE_LAST_INSERTED] = (SELECT MAX([DATE_LAST_INSERTED])  FROM [VWSSTATIC].[CBS_POPULATION])
        AND [AGE_GROUP] IS NOT NULL
    GROUP BY [DATE_OF_POLL]
    ORDER BY [DATE_OF_POLL];
    
    COMMIT;
END
GO

-- %% [markdown]
-- #### SAFETY REGIONS

-- %%
-- COPYRIGHT (C) 2020 DE STAAT DER NEDERLANDEN, MINISTERIE VAN   VOLKSGEZONDHEID, WELZIJN EN SPORT.
-- LICENSED UNDER THE EUROPEAN UNION PUBLIC LICENCE V. 1.2 - SEE HTTPS://GITHUB.COM/MINVWS/NL-CONTACT-TRACING-APP-COORDINATIONFOR MORE INFORMATION.

CREATE OR ALTER PROCEDURE [DBO].[SP_CBS_POPULATION_VR_STATIC_TO_STATIC]
AS
BEGIN

    BEGIN TRANSACTION;

    INSERT INTO [VWSSTATIC].[CBS_POPULATION_VR]( 
        [VR_CODE], 
        [DATE_OF_POLL], 
        [POPULATION] 
    )
    SELECT 
        [VR_CODE],
        [DATE_OF_POLL],
        SUM([POPULATION])
    FROM [VWSSTATIC].[CBS_POPULATION]
    WHERE [DATE_LAST_INSERTED] = ( SELECT MAX([DATE_LAST_INSERTED])  FROM [VWSSTATIC].[CBS_POPULATION] )
        AND [AGE_GROUP] IS NOT NULL
    GROUP BY [VR_CODE], [DATE_OF_POLL]
    ORDER BY [VR_CODE], [DATE_OF_POLL];
    
    COMMIT;
END
GO

-- %% [markdown]
-- #### MUNICIPALITIES

-- %%
-- COPYRIGHT (C) 2020 DE STAAT DER NEDERLANDEN, MINISTERIE VAN   VOLKSGEZONDHEID, WELZIJN EN SPORT.
-- LICENSED UNDER THE EUROPEAN UNION PUBLIC LICENCE V. 1.2 - SEE HTTPS://GITHUB.COM/MINVWS/NL-CONTACT-TRACING-APP-COORDINATIONFOR MORE INFORMATION.

CREATE OR ALTER PROCEDURE [DBO].[SP_CBS_POPULATION_GM_STATIC_TO_STATIC]
AS
BEGIN

    BEGIN TRANSACTION;

    INSERT INTO [VWSSTATIC].[CBS_POPULATION_GM] ( [GM_CODE], [DATE_OF_POLL], [POPULATION] )
    SELECT
        [GM_CODE],
        [DATE_OF_POLL],
        SUM([POPULATION])
    FROM [VWSSTATIC].[CBS_POPULATION]
    WHERE [DATE_LAST_INSERTED] = ( SELECT MAX([DATE_LAST_INSERTED])  FROM [VWSSTATIC].[CBS_POPULATION] )
        AND [AGE_GROUP] IS NOT NULL
    GROUP BY [GM_CODE], [DATE_OF_POLL]
    ORDER BY [DATE_OF_POLL], [GM_CODE];

    COMMIT;
END
GO

-- %% [markdown]
-- #### AGE GROUP HOSPITAL IC

-- %%
-- COPYRIGHT (C) 2020 DE STAAT DER NEDERLANDEN, MINISTERIE VAN VOLKSGEZONDHEID, WELZIJN EN SPORT.
-- LICENSED UNDER THE EUROPEAN UNION PUBLIC LICENCE V. 1.2 - SEE HTTPS://GITHUB.COM/MINVWS/NL-CONTACT-TRACING-APP-COORDINATION FOR MORE INFORMATION.

CREATE OR ALTER PROCEDURE [DBO].[SP_CBS_POPULATION_PER_AGE_GROUP_HOSPITAL_IC_STATIC_TO_STATIC]
AS
BEGIN

    BEGIN TRANSACTION;

    WITH CTE AS (
        SELECT 
            [DATE_OF_POLL],
            [AGE_GROUP],
            SUM([POPULATION]) AS [POPULATION]
        FROM [VWSSTATIC].[CBS_POPULATION]
        WHERE [DATE_LAST_INSERTED] = (SELECT MAX([DATE_LAST_INSERTED]) FROM [VWSSTATIC].[CBS_POPULATION])
            AND [AGE_GROUP] IS NOT NULL
        GROUP BY [AGE_GROUP], [DATE_OF_POLL]
    )
    INSERT INTO [VWSSTATIC].[CBS_POPULATION_PER_AGE_GROUP_HOSPITAL_IC] (
        [DATE_OF_POLL],
        [AGE_GROUP],
        [POPULATION],
        [POPULATION_TOTAL],
        [INHABITANTS_PERCENTAGE]
    )
    SELECT
        [DATE_OF_POLL],
        [AGE_GROUP],
        [POPULATION],
        SUM([POPULATION]) OVER (PARTITION BY [DATE_OF_POLL]),
        ROUND(CAST([POPULATION] AS FLOAT) / SUM([POPULATION]) OVER (PARTITION BY [DATE_OF_POLL]),3)
    FROM CTE
    ORDER BY [DATE_OF_POLL], [AGE_GROUP];
    
    COMMIT;
END
GO

-- %% [markdown]
-- #### AGE GROUP DECEASED

-- %%
-- COPYRIGHT (C) 2020 DE STAAT DER NEDERLANDEN, MINISTERIE VAN VOLKSGEZONDHEID, WELZIJN EN SPORT.
-- LICENSED UNDER THE EUROPEAN UNION PUBLIC LICENCE V. 1.2 - SEE HTTPS://GITHUB.COM/MINVWS/NL-CONTACT-TRACING-APP-COORDINATION FOR MORE INFORMATION.

CREATE OR ALTER PROCEDURE [DBO].[SP_CBS_POPULATION_PER_AGE_GROUP_DECEASED_STATIC_TO_STATIC]
AS
BEGIN

    BEGIN TRANSACTION;

    WITH CTE AS (
        SELECT 
            [DATE_OF_POLL],
            [AGE_GROUP],
            SUM([POPULATION]) AS [POPULATION]
        FROM [VWSSTATIC].[CBS_POPULATION]
        WHERE [DATE_LAST_INSERTED] = (SELECT MAX([DATE_LAST_INSERTED]) FROM [VWSSTATIC].[CBS_POPULATION])
            AND [AGE_GROUP] IS NOT NULL
        GROUP BY [AGE_GROUP], [DATE_OF_POLL]
    )
    INSERT INTO [VWSSTATIC].[CBS_POPULATION_PER_AGE_GROUP_DECEASED] (
        [DATE_OF_POLL],
        [AGE_GROUP],
        [POPULATION],
        [POPULATION_TOTAL],
        [INHABITANTS_PERCENTAGE]
    )
    SELECT
        [DATE_OF_POLL],
        [AGE_GROUP],
        [POPULATION],
        SUM([POPULATION]) OVER (PARTITION BY [DATE_OF_POLL]),
        ROUND(CAST([POPULATION] AS FLOAT) / SUM([POPULATION]) OVER (PARTITION BY [DATE_OF_POLL]),3)
    FROM CTE
    ORDER BY [DATE_OF_POLL], [AGE_GROUP];
    
    COMMIT;
END
GO

-- %% [markdown]
-- ### AGE GROUPS

-- %%
-- COPYRIGHT (C) 2020 DE STAAT DER NEDERLANDEN, MINISTERIE VAN VOLKSGEZONDHEID, WELZIJN EN SPORT.
-- LICENSED UNDER THE EUROPEAN UNION PUBLIC LICENCE V. 1.2 - SEE HTTPS://GITHUB.COM/MINVWS/NL-CONTACT-TRACING-APP-COORDINATION FOR MORE INFORMATION.

CREATE OR ALTER PROCEDURE [DBO].[SP_CBS_POPULATION_PER_AGE_GROUP_STATIC_TO_STATIC]
AS
BEGIN

    BEGIN TRANSACTION;

    INSERT INTO [VWSSTATIC].[CBS_POPULATION_PER_AGE_GROUP] (
        [DATE_OF_POLL],
        [AGE_GROUP],
        [POPULATION]
    )
    SELECT
        [DATE_OF_POLL],
        [AGE_GROUP],
        SUM([POPULATION]) AS [POPULATION]
    FROM [VWSSTATIC].[CBS_POPULATION]
    WHERE [DATE_LAST_INSERTED] = (SELECT MAX([DATE_LAST_INSERTED]) FROM [VWSSTATIC].[CBS_POPULATION])
        AND [AGE_GROUP] IS NOT NULL
    GROUP BY [AGE_GROUP], [DATE_OF_POLL]
    ORDER BY [DATE_OF_POLL], [AGE_GROUP];
    
    COMMIT;
END;
GO

-- %% [markdown]
-- # **DATATINO CONFIGURATIONS**
--
-- ---

-- %% [markdown]
-- ### WORKFLOWS

-- %%
-- COPYRIGHT (C) 2020 DE STAAT DER NEDERLANDEN, MINISTERIE VAN   VOLKSGEZONDHEID, WELZIJN EN SPORT.
-- LICENSED UNDER THE EUROPEAN UNION PUBLIC LICENCE V. 1.2 - SEE HTTPS://GITHUB.COM/MINVWS/NL-CONTACT-TRACING-APP-COORDINATIONFOR MORE INFORMATION.

-- 1) UPSERT WORKFLOW(S).....
DECLARE @workflow_name NVARCHAR(50) = 'CBS_POPULATION',
        @workflow_alternative_name NVARCHAR(50),
        @workflow_id INT,        
        @workflow_description VARCHAR(256),
        @is_active INT;

SET @workflow_alternative_name = CONCAT(N'STATIC_', @workflow_name);

-- 1.1) SET ENVIRONMENTAL VARIABLES.....
SET @is_active = CASE LOWER('#{ Environment }#')
    WHEN 'production' THEN 1
    WHEN 'acceptance' THEN 1
    ELSE 1
END;

SELECT TOP(1)
    @workflow_id = workflows.[ID]
FROM [DATATINO_ORCHESTRATOR_1].[WORKFLOWS] workflows
INNER JOIN [DATATINO_ORCHESTRATOR_1].[V_WORKFLOWS] v_workflows ON v_workflows.[DATAFLOW_ID] = workflows.[DATAFLOW_ID] AND v_workflows.[ID] = workflows.[ID]
WHERE v_workflows.[NAME] = @workflow_alternative_name;

SET @workflow_description = CONCAT('WORKFLOW: ', @workflow_alternative_name);

EXECUTE [DATATINO_ORCHESTRATOR_1].[UPSERT_WORKFLOW]
    @id = @workflow_id, 
    @workflow_name = @workflow_alternative_name,
    @description = @workflow_description,
    @schedule = '0 0 1 */3 *', -- AT 12:00 AM, ON DAY 1 OF THE MONTH, EVERY 3 MONTHS
    @active = @is_active;

-- 2) UPSERT SOURCE(S).....
DECLARE @source NVARCHAR(256),
        @source_id INT,
        @source_name NVARCHAR(256),
        @source_description NVARCHAR(256),
        @target_name VARCHAR(256),
        @location_type VARCHAR(50),
        @security_profile VARCHAR(50);

-- 2.1) SET ENVIRONMENTAL VARIABLES.....
SET @source = CASE LOWER('#{ Environment }#')
    WHEN 'production' THEN 'datafiles/STATIC/populatie_data.csv'
    WHEN 'acceptance' THEN 'datafiles/STATIC/populatie_data.csv'
    ELSE 'datafiles/STATIC/populatie_data.csv'
END;

SET @location_type = CASE LOWER('#{ Environment }#')
    WHEN 'production' THEN 'AzureBlob'
    WHEN 'acceptance' THEN 'AzureBlob'
    ELSE 'AzureBlob'
END;

SET @security_profile = CASE LOWER('#{ Environment }#')
    WHEN 'production' THEN 'RIVM'
    WHEN 'acceptance' THEN 'RIVM'
    ELSE 'RIVM'
END;

-- 2.2) UPSERT TABLE SOURCE(S): STATIC......
SET @source_id = NULL;
SET @source_name = CONCAT('SOURCE_', @workflow_name);
SET @source_description = CONCAT('LOAD: ', @workflow_name);
SET @target_name = CONCAT('VWSSTATIC.', @workflow_name);

SELECT TOP(1)
    @source_id = [ID]
FROM [DATATINO_ORCHESTRATOR_1].[SOURCES]
WHERE [NAME] = @source_name;

EXECUTE [DATATINO_ORCHESTRATOR_1].[UPSERT_SOURCE]
    @id = @source_id,
    @source_name = @source_name,
    @description = @source_description,
    @source = @source,
    @source_columns = 'Gemeente_code|Gemeente|Leeftijd|Geslacht|Datum_peiling|Populatie|Veiligheidsregio_code|Veiligheidsregio_naam|Provincie_code|Provincie_naam|GGD_code|GGD_naam',
    @target_columns = 'GM_CODE|GM_NAME|AGE|GENDER|DATE_OF_POLL|POPULATION|VR_CODE|VR_NAME|PROVINCE_CODE|PROVINCE_NAME|GGD_CODE|GGD_NAME',
    @target_name = @target_name,
    @source_type = 'CsvFile',
    @location_type = @location_type,
    @delimiter_type = 'SemiColon',
    @security_profile= @security_profile;

-- 2.3) UPSERT STORED PROCEDURE SOURCE(S): STATIC TO STATIC......
SET @source_id = NULL;
SET @source = CONCAT('dbo.SP_', @workflow_name, '_STATIC_TO_STATIC');
SET @source_name = CONCAT('SOURCE_SP_', @workflow_name, '_STATIC_TO_STATIC');
SET @source_description = CONCAT('MAP: ', @workflow_name, ' FROM STATIC TO STATIC');

SELECT TOP(1)
    @source_id = [ID]
FROM [DATATINO_ORCHESTRATOR_1].[SOURCES]
WHERE [NAME] = @source_name;

EXECUTE [DATATINO_ORCHESTRATOR_1].[UPSERT_SOURCE]
    @id = @source_id,
    @source_name = @source_name,
    @description = @source_description,
    @source = @source,
    @source_columns = null,
    @target_columns = null,
    @target_name = null,
    @source_type = 'StoredProcedure',
    @location_type = 'N/A',
    @delimiter_type = 'N/A',
    @security_profile= @security_profile;

-- 3) UPSERT PROCESS(ES).....
DECLARE @process_id INT,
        @process_name NVARCHAR(256),
        @process_description NVARCHAR(256),
        @process_source_name VARCHAR(256);

-- 3.1) UPSERT TABLE PROCESS(ES): STATIC......
SET @process_id = NULL;
SET @process_name = CONCAT('PROCESS_', @workflow_name);
SET @process_description = CONCAT('LOAD: ', @workflow_name);
SET @process_source_name = CONCAT('SOURCE_', @workflow_name);

SELECT TOP(1)
    @process_id = processes.[ID]
FROM [DATATINO_ORCHESTRATOR_1].[PROCESSES] processes
INNER JOIN [DATATINO_ORCHESTRATOR_1].[V_WORKFLOWS] v_workflows ON v_workflows.[ID] = processes.[WORKFLOW_ID]
INNER JOIN [DATATINO_ORCHESTRATOR_1].[V_PROCESSES] v_processes ON v_processes.[PROCESS_ID] = processes.[ID]
WHERE v_processes.[PROCESS_NAME] = @process_name 
    AND v_workflows.[NAME] = @workflow_alternative_name;

EXECUTE [DATATINO_ORCHESTRATOR_1].[UPSERT_PROCESS]
    @id = @process_id,
    @process_name = @process_name,
    @description = @process_description,
    @source_name = @process_source_name,
    @schedule = '* * * * *',
    @workflow_name = @workflow_alternative_name,
    @active = 1;

-- 3.2) UPSERT STORED PROCEDURE PROCESS(S): STATIC TO STATIC......
SET @process_id = NULL;
SET @process_name = CONCAT('PROCESS_SP_', @workflow_name, '_STATIC_TO_STATIC');
SET @process_description = CONCAT('MAP: ', @workflow_name, ' FROM STATIC TO STATIC');
SET @process_source_name = CONCAT('SOURCE_SP_', @workflow_name, '_STATIC_TO_STATIC');

SELECT TOP(1)
    @process_id = processes.[ID]
FROM [DATATINO_ORCHESTRATOR_1].[PROCESSES] processes
INNER JOIN [DATATINO_ORCHESTRATOR_1].[V_WORKFLOWS] v_workflows ON v_workflows.[ID] = processes.[WORKFLOW_ID]
INNER JOIN [DATATINO_ORCHESTRATOR_1].[V_PROCESSES] v_processes ON v_processes.[PROCESS_ID] = processes.[ID]
WHERE v_processes.[PROCESS_NAME] = @process_name 
    AND v_workflows.[NAME] = @workflow_alternative_name;

EXECUTE [DATATINO_ORCHESTRATOR_1].[UPSERT_PROCESS]
    @id = @process_id,
    @process_name = @process_name,
    @description = @process_description,
    @source_name = @process_source_name,
    @schedule = '* * * * *',
    @workflow_name = @workflow_alternative_name,
    @active = 1;

-- 4) UPSERT DEPENDENC(Y)(IES).....
DECLARE @dependency_id INT,
        @dependency_name NVARCHAR(256),
        @dependency_description NVARCHAR(256),
        @dependency_dataflow_name NVARCHAR(256),
        @dependency_process_name NVARCHAR(256);

-- 4.1) UPSERT STATIC TO STORED PROCEDURE DEPENDENC(Y)(IES).....
SET @dependency_id = NULL;
SET @dependency_name = CONCAT('DEPENDENCY_', @workflow_name,'_STATIC_TO_STATIC');
SET @dependency_dataflow_name = CONCAT('PROCESS_SP_', @workflow_name, '_STATIC_TO_STATIC');
SET @dependency_process_name = CONCAT('PROCESS_', @workflow_name);
SET @dependency_description = CONCAT('TRIGGER ', @dependency_dataflow_name,' AFTER ', @dependency_process_name ,' HAS FINISHED');

SELECT TOP(1)
    @dependency_id = dependencies.[ID]
FROM [DATATINO_ORCHESTRATOR_1].[DEPENDENCIES] dependencies
INNER JOIN [DATATINO_ORCHESTRATOR_1].[V_DEPENDENCIES] v_dependencies ON v_dependencies.[ID] = dependencies.[ID]
WHERE dependencies.[NAME] = @dependency_name
    AND v_dependencies.[WORKFLOW_NAME] = @workflow_alternative_name;

EXECUTE [DATATINO_ORCHESTRATOR_1].[UPSERT_DEPENDENCY]
    @id = @dependency_id,
    @dataflow_name = @dependency_dataflow_name,
    @dataflowtype_id = 2,
    @dependency_name = @dependency_process_name,
    @dependencytype_id = 2,
    @workflow_name = @workflow_alternative_name,
    @name = @dependency_name,
    @description = @dependency_description,
    @active = 1;
GO
